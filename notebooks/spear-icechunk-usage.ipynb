# %%
# Using the saved icechunk store - persistency check 
import icechunk, xarray as xr

storage = icechunk.local_filesystem_storage(
    path='spear-tas-test')

config = icechunk.RepositoryConfig.default()
config.set_virtual_chunk_container(icechunk.VirtualChunkContainer("s3://noaa-gfdl-spear-large-ensembles-pds/", icechunk.s3_store(region="us-east-1")))
credentials = icechunk.containers_credentials({"s3://noaa-gfdl-spear-large-ensembles-pds/": icechunk.s3_credentials(anonymous=True)})
repo = icechunk.Repository.open(storage, config, credentials)

session = repo.readonly_session(branch="main")
ds_test = xr.open_zarr(session.store, consolidated=False)
print(ds_test)
# Out:
#   2025-10-03T14:55:29.776276Z  WARN icechunk::storage::object_store: The LocalFileSystem storage is not safe for concurrent commits. If more than one thread/process will attempt to commit at the same time, prefer using object stores.
#     at icechunk/src/storage/object_store.rs:80
# /nbhome/Aparna.Radhakrishnan/conda/envs/catalogbuilder/lib/python3.12/site-packages/zarr/codecs/numcodecs/_codecs.py:139: ZarrUserWarning: Numcodecs codecs are not in the Zarr version 3 specification and may not be supported by other zarr implementations.
#   super().__init__(**codec_config)
# <xarray.Dataset> Size: 936MB
# Dimensions:    (time: 1128, bnds: 2, lat: 360, lon: 576)
# Coordinates:
#   * time       (time) object 9kB 1921-01-16 12:00:00 ... 2014-12-16 12:00:00
#   * lon        (lon) float64 5kB 0.3125 0.9375 1.562 2.188 ... 358.4 359.1 359.7
#   * bnds       (bnds) float64 16B 1.0 2.0
#   * lat        (lat) float64 3kB -89.75 -89.25 -88.75 ... 88.75 89.25 89.75
# Data variables:
#     time_bnds  (time, bnds) object 18kB dask.array<chunksize=(1, 2), meta=np.ndarray>
#     lat_bnds   (lat, bnds) float64 6kB dask.array<chunksize=(360, 2), meta=np.ndarray>
#     tas        (time, lat, lon) float32 936MB dask.array<chunksize=(1, 360, 576), meta=np.ndarray>
#     lon_bnds   (lon, bnds) float64 9kB dask.array<chunksize=(576, 2), meta=np.ndarray>
# Attributes: (12/28)
#     history:                File was processed by fremetar (GFDL analog of CM...
#     table_id:               Amon
#     contact:                gfdl.climate.model.info@noaa.gov
#     experiment:             all-forcing simulation for 1921 to 2014
#     experiment_id:          historical
#     Conventions:            CF-1.7
#     ...                     ...
#     references:             SPEAR: The next generation GFDL modeling system f...
#     title:                  NOAA GFDL GFDL-SPEAR-MED, all-forcing simulation ...
#     gfdl_experiment_name:   SPEAR-MED.historical.r10
#     license:                CC-BY-SA-4.0
#     forcing:                CMIP6 historical
#     external_variables:     areacella

# %%
ds_test.tas.isel(time=10)
# Out:
# <xarray.DataArray 'tas' (lat: 360, lon: 576)> Size: 829kB
# dask.array<getitem, shape=(360, 576), dtype=float32, chunksize=(360, 576), chunktype=numpy.ndarray>
# Coordinates:
#     time     object 8B 1921-11-16 00:00:00
#   * lon      (lon) float64 5kB 0.3125 0.9375 1.562 2.188 ... 358.4 359.1 359.7
#   * lat      (lat) float64 3kB -89.75 -89.25 -88.75 -88.25 ... 88.75 89.25 89.75
# Attributes:
#     long_name:      Near-Surface Air Temperature
#     units:          K
#     valid_range:    [100.0, 400.0]
#     cell_methods:   time: mean
#     interp_method:  conserve_order2
#     standard_name:  air_temperature
#     cell_measures:  area: areacella
